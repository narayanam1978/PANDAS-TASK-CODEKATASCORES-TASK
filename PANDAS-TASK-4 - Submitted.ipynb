# %%
#Task - 4 : PANDAS  SUBMITTED BY: RANGANADH NARAYANAM GUVI MASTER DS  DATE OF SUBMISSION: 03-04-2022 DUE DATE: 10-04-2022

# %%
#import necessary libraries
import pandas as pd

# %%
#merge those two csv files (after getting as dataframes, get them as a single dataframe)
df1 = pd.read_csv('college_1.csv')
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df1["Name"]
# Out:
# 0          A.Dharani
# 1        V.JEEVITHA
# 2        HEMAVATHI.R
# 3        Mugunthan S
# 4        Sathammai.S
#            ...
# 79      KarthikeyanS
# 80          BARATH.P
# 81     N.Ajith kumar
# 82      mohamed nabi
# 83    yaser ahamed.A
# Name: Name, Length: 84, dtype: object

# %%
print(df1.to_string())
# Out:
#                           Name  python   mysql  Previous Geekions  CodeKata Score                                 Department  Rising
# 0                    A.Dharani    82.0   20.00              24500           24500           Computer Science and Engineering       0
# 1                  V.JEEVITHA     82.0   20.00              21740           21740           Computer Science and Engineering       0
# 2                  HEMAVATHI.R   100.0  100.00              19680           19680           Computer Science and Engineering       0
# 3                  Mugunthan S   100.0   47.00              10610           10610           Computer Science and Engineering       0
# 4                  Sathammai.S   100.0    8.00               8980            8980           Computer Science and Engineering       0
# 5                 NIVEESHWAR S   100.0    0.00               8200            8200           Computer Science and Engineering       0
# ...

# %%
#merge those two csv files (after getting as dataframes, get them as a single dataframe)
df2 = pd.read_csv('college_2.csv')
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
#mergedRes = pd.merge(df1, df2)
#mergedRes
# Out:
# C:\Users\ANACONDA-2021\lib\site-packages\pandas\core\reshape\merge.py:1113: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
# Empty DataFrame
# Columns: [Name, python, mysql, Previous Geekions, CodeKata Score, Department, Rising, python_en, computational_thinking]
# Index: []

# %%
##merge those two csv files (after getting as dataframes, get them as a single dataframe)

mergedRes = pd.merge(df1, df2, on ='Name', how ="outer")

# %%
mergedRes
# Out:
#               Name  python_x  mysql_x  Previous Geekions_x  CodeKata Score_x  \
# 0        A.Dharani      82.0     20.0              24500.0           24500.0
# 1      V.JEEVITHA       82.0     20.0              21740.0           21740.0
# 2      HEMAVATHI.R     100.0    100.0              19680.0           19680.0
# 3      Mugunthan S     100.0     47.0              10610.0           10610.0
# 4      Sathammai.S     100.0      8.0               8980.0            8980.0
# ..             ...       ...      ...                  ...               ...
# 114  praveen raj j       NaN      NaN                  NaN               NaN
# 115     AMARNATH D       NaN      NaN                  NaN               NaN
# 116           bala       NaN      NaN                  NaN               NaN
# 117           XY Z       NaN      NaN                  NaN               NaN
# 118      Hariharan       NaN      NaN                  NaN               NaN
#
# ...

# %%
#merge those two csv files (after getting as dataframes, get them as a single dataframe)
file1 = "college_1.csv"
file2 = "college_2.csv"
dataFrame = pd.concat(map(pd.read_csv, [file1, file2]), ignore_index=True)
dataFrame
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
#merge those two csv files (after getting as dataframes, get them as a single dataframe)

df3 = df1.merge(df2, on=["Name"], how = "outer")
df3
# Out:
#               Name  python_x  mysql_x  Previous Geekions_x  CodeKata Score_x  \
# 0        A.Dharani      82.0     20.0              24500.0           24500.0
# 1      V.JEEVITHA       82.0     20.0              21740.0           21740.0
# 2      HEMAVATHI.R     100.0    100.0              19680.0           19680.0
# 3      Mugunthan S     100.0     47.0              10610.0           10610.0
# 4      Sathammai.S     100.0      8.0               8980.0            8980.0
# ..             ...       ...      ...                  ...               ...
# 114  praveen raj j       NaN      NaN                  NaN               NaN
# 115     AMARNATH D       NaN      NaN                  NaN               NaN
# 116           bala       NaN      NaN                  NaN               NaN
# 117           XY Z       NaN      NaN                  NaN               NaN
# 118      Hariharan       NaN      NaN                  NaN               NaN
#
# ...

# %%
#merge those two csv files (after getting as dataframes, get them as a single dataframe)
file1 = "college_1.csv"
file2 = "college_2.csv"
dataFrame = pd.concat(map(pd.read_csv, [file1, file2]), ignore_index=True)
dataFrame
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
#Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)
df5 = pd.read_csv("college_1.csv")
sorted_df = df5.sort_values(by=["CodeKata Score"], ascending=False)
sorted_df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
#consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv
df6 = sorted_df[sorted_df["CodeKata Score"] >= 15000]
df6
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %%
df7 = sorted_df[sorted_df["CodeKata Score"] < 15000]
df7
# Out:
#                     Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3            Mugunthan S   100.0   47.0              10610           10610
# 4            Sathammai.S   100.0    8.0               8980            8980
# 5           NIVEESHWAR S   100.0    0.0               8200            8200
# 6          KALAIARASAN K    85.0   47.0               7750            7880
# 7   MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# ..                   ...     ...    ...                ...             ...
# 79          KarthikeyanS    45.0    0.0                  0               0
# 80              BARATH.P    29.0    0.0                  0               0
# 81         N.Ajith kumar    82.0    0.0                  0               0
# 82          mohamed nabi     0.0    0.0                  0               0
# 83        yaser ahamed.A     0.0   27.0                  0               0
#
#                                    Department  Rising
# ...

# %%
df8 = sorted_df[(sorted_df["CodeKata Score"] >= 10000)]
df8
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0

# %%
#if 10000<codekata score<15000 (Reached_expectations.csv)
df9 = sorted_df[(sorted_df["CodeKata Score"] >= 10000) & (sorted_df["CodeKata Score"] < 15000)]
df9
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3  Mugunthan S   100.0   47.0              10610           10610
#
#                          Department  Rising
# 3  Computer Science and Engineering       0

# %%
#if 7000<codekata score<10000 (Needs_Improvement.csv)
df10 = sorted_df[(sorted_df["CodeKata Score"] >= 7000) & (sorted_df["CodeKata Score"] < 10000)]
df10
# Out:
#                    Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4           Sathammai.S   100.0    8.0               8980            8980
# 5          NIVEESHWAR S   100.0    0.0               8200            8200
# 6         KALAIARASAN K    85.0   47.0               7750            7880
# 7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
#
#                                   Department  Rising
# 4           Computer Science and Engineering       0
# 5           Computer Science and Engineering       0
# 6  Electronics and Communication Engineering     130
# 7           Computer Science and Engineering       0

# %%
#if codekate score < 7000 (Unsatisfactory.csv)
df11 = sorted_df[(sorted_df["CodeKata Score"] < 7000)]
df11
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 79     KarthikeyanS    45.0   0.00                  0               0
# 80         BARATH.P    29.0   0.00                  0               0
# 81    N.Ajith kumar    82.0   0.00                  0               0
# 82     mohamed nabi     0.0   0.00                  0               0
# 83   yaser ahamed.A     0.0  27.00                  0               0
#
#                                    Department  Rising
# 8   Electronics and Communication Engineering       0
# ...

# %%
#writing to new CSV files
#df6 to write to Exceeded expectations.csv
df6.to_csv(f'Exceeded expectations.csv',index=False)

# %%
#reading df6 to verify
#correct process
df61 = pd.read_csv('Exceeded expectations.csv')
df61
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0

# %%
#df9 to write to Reached_expectations.csv
df9.to_csv(f'Reached_expectations.csv',index=False)

# %%
#reading df9 to verify
df91 = pd.read_csv('Reached_expectations.csv')
df91
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0  Mugunthan S   100.0   47.0              10610           10610
#
#                          Department  Rising
# 0  Computer Science and Engineering       0

# %%
#df10 to write to Needs_Improvement.csv
df10.to_csv(f'Needs_Improvement.csv',index=False)

# %%
#reading df10 to verify
df101 = pd.read_csv('Needs_Improvement.csv')
df101
# Out:
#                    Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           Sathammai.S   100.0    8.0               8980            8980
# 1          NIVEESHWAR S   100.0    0.0               8200            8200
# 2         KALAIARASAN K    85.0   47.0               7750            7880
# 3  MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
#
#                                   Department  Rising
# 0           Computer Science and Engineering       0
# 1           Computer Science and Engineering       0
# 2  Electronics and Communication Engineering     130
# 3           Computer Science and Engineering       0

# %%
#df11 to write to Needs_Improvement.csv
df11.to_csv(f'Unsatisfactory.csv',index=False)

# %%
#reading df11 to verify
df111 = pd.read_csv('Unsatisfactory.csv')
df111
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 71     KarthikeyanS    45.0   0.00                  0               0
# 72         BARATH.P    29.0   0.00                  0               0
# 73    N.Ajith kumar    82.0   0.00                  0               0
# 74     mohamed nabi     0.0   0.00                  0               0
# 75   yaser ahamed.A     0.0  27.00                  0               0
#
#                                    Department  Rising
# 0   Electronics and Communication Engineering       0
# ...

# %%
#Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)
df12 = pd.read_csv("college_2.csv")
sorted_df1 = df12.sort_values(by=["CodeKata Score"], ascending=False)
sorted_df1
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
#consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv
df13 = sorted_df1[sorted_df1["CodeKata Score"] >= 15000]
df13
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K     100          0     31                       9
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
#
#    Rising
# 0       0

# %%
df13.to_csv(f'Exceeded expectations1.csv',index=False)

# %%
df131 = pd.read_csv('Exceeded expectations1.csv')
df131
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K     100          0     31                       9
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
#
#    Rising
# 0       0

# %%
#if 10000<codekata score<15000 (Reached_expectations.csv)
df14 = sorted_df1[(sorted_df1["CodeKata Score"] >= 10000) & (sorted_df1["CodeKata Score"] < 15000)]
df14
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
#
#                                   Department  Rising
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0

# %%
df14.to_csv(f'Reached_expectations1.csv',index=False)

# %%
df141 = pd.read_csv('Reached_expectations1.csv')
df141
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0            Chandru       0         20      0                       0
# 1  Ganesh Ramkumar R      -1         55     24                       6
# 2    Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              14150           14490
# 1               8790           10790
# 2              10040           10040
#
#                                   Department  Rising
# 0           Computer Science and Engineering     340
# 1           Computer Science and Engineering    2000
# 2  Electronics and Communication Engineering       0

# %%
df15 = sorted_df1[(sorted_df1["CodeKata Score"] >= 7000) & (sorted_df1["CodeKata Score"] < 10000)]
df15
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 12                JPradhap     100          0      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 14               Praneetha      -1         23    100                      -1
# ...

# %%
df15.to_csv(f'Needs_Improvement1.csv',index=False)

# %%
df151 = pd.read_csv('Needs_Improvement1.csv')
df151
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0                VIINU V P      -1        100     24                      -1
# 1               Poojitha Y       0         78     35                       0
# 2   Gowtham Chandrasekaran      -1          0      0                       3
# 3                Gowtham R      -1         60      4                       6
# 4                 shifak N      58          0      0                       0
# 5                  Balaji       -1        100     20                       0
# 6                 Rushitha      -1         15     62                       9
# 7     Balaraman Muthupandi      -1          9      0                       0
# 8                 JPradhap     100          0      0                       0
# 9            SRIRAMKUMAR B      -1          0      0                       0
# 10               Praneetha      -1         23    100                      -1
# ...

# %%
df16 = sorted_df1[(sorted_df1["CodeKata Score"] < 7000)]
df16
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 18     Narasimhan Y L      -1         -1      0                       0
# 19       Leelakrishna      -1          6      4                       0
# 20     PremsagarReddy      -1         20      0                       0
# 21          pradeeban      16         20     24                       0
# 22        santhoshini      -1         43      0                       0
# 23         MUKESH S M      -1         46      0                       0
# 24      P.GOVARDHANAN      -1         40      0                      -1
# 25       SHAIK DANISH      -1         43      0                       0
# 26          sridhar.s      -1         52      0                       0
# 27  Vimalesh Fernando      -1          0      0                       0
# 28      M.Karthikeyan      -1          0      4                       6
# 29          Abishak s      -1         55     35                       6
# ...

# %%
df16.to_csv(f'Unsatisfactory1.csv',index=False)

# %%
df161 = pd.read_csv('Unsatisfactory1.csv')
df161
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 0      Narasimhan Y L      -1         -1      0                       0
# 1        Leelakrishna      -1          6      4                       0
# 2      PremsagarReddy      -1         20      0                       0
# 3           pradeeban      16         20     24                       0
# 4         santhoshini      -1         43      0                       0
# 5          MUKESH S M      -1         46      0                       0
# 6       P.GOVARDHANAN      -1         40      0                      -1
# 7        SHAIK DANISH      -1         43      0                       0
# 8           sridhar.s      -1         52      0                       0
# 9   Vimalesh Fernando      -1          0      0                       0
# 10      M.Karthikeyan      -1          0      4                       6
# 11          Abishak s      -1         55     35                       6
# ...

# %%
df1 = pd.read_csv('college_1.csv')
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
#Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)
df20 = df1[["Previous Geekions","CodeKata Score"]].mean()
df20
# Out:
# Previous Geekions    2904.523810
# CodeKata Score       2906.071429
# dtype: float64

# %%
#No of students participated
index = df1.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 84

# %%
##Average completion of python course or my_sql or python english or computational thinking
df100 = pd.read_csv('college_2.csv')
df100
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
#Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)
df21 = df100[["Previous Geekions","CodeKata Score"]].mean()
df21
# Out:
# Previous Geekions    6093.142857
# CodeKata Score       6801.428571
# dtype: float64

# %%
#No of students participated
index = df100.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 35

# %%
#Average completion of python course or my_sql or python english or computational thinking
#completion of python course above 30 marks pass 
df22 = df100[(df100["python"] > 30)]
df22
# Out:
#              Name  python  python_en  mysql  computational_thinking  \
# 0   ASHOK KUMAR K     100          0     31                       9
# 8        shifak N      58          0      0                       0
# 12       JPradhap     100          0      0                       0
# 32           bala      32         49      0                      -1
#
#     Previous Geekions  CodeKata Score  \
# 0               19400           19400
# 8                5180            8320
# 12               7340            8030
# 32               1720            1720
#
#                                    Department  Rising
# 0      Electronics and Electrical Engineering       0
# 8      Electronics and Electrical Engineering    3140
# 12     Electronics and Electrical Engineering     690
# 32  Electronics and Communication Engineering       0

# %%
df23 = df22["python"].mean()
df23
# Out:
# 72.5

# %%
#total number of pass in python
A = []
index = df22.index
number_of_rows = len(index)
print(number_of_rows)
A.append(number_of_rows)
# Out:
# 4

# %%
#Average completion of python course or my_sql or python english or computational thinking
#completion of python en course above 30 marks pass 
df24 = df100[(df100["python_en"] > 30)]
df24
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 2   Ganesh Ramkumar R      -1         55     24                       6
# 4           VIINU V P      -1        100     24                      -1
# 5          Poojitha Y       0         78     35                       0
# 7           Gowtham R      -1         60      4                       6
# 9             Balaji       -1        100     20                       0
# 16            Guhan S      -1         72     35                      39
# 17       Suryarajan S      -1         63     31                       0
# 22        santhoshini      -1         43      0                       0
# 23         MUKESH S M      -1         46      0                       0
# 24      P.GOVARDHANAN      -1         40      0                      -1
# 25       SHAIK DANISH      -1         43      0                       0
# 26          sridhar.s      -1         52      0                       0
# ...

# %%
#total number of pass in python
index = df24.index
number_of_rows = len(index)
print(number_of_rows)
A.append(number_of_rows)
# Out:
# 15

# %%
#Average completion of python course or my_sql or python english or computational thinking
#completion of mysql course above 30 marks pass 
df25 = df100[(df100["mysql"] > 30)]
df25
# Out:
#                Name  python  python_en  mysql  computational_thinking  \
# 0     ASHOK KUMAR K     100          0     31                       9
# 3   Bodipudi Harini      -1          0     35                      -1
# 5        Poojitha Y       0         78     35                       0
# 10         Rushitha      -1         15     62                       9
# 14        Praneetha      -1         23    100                      -1
# 16          Guhan S      -1         72     35                      39
# 17     Suryarajan S      -1         63     31                       0
# 29        Abishak s      -1         55     35                       6
#
#     Previous Geekions  CodeKata Score  \
# 0               19400           19400
# 3               10040           10040
# 5                7210            8970
# 10               7470            8090
# 14               7170            7730
# 16               7310            7630
# 17               6710            7550
# ...

# %%
#total number of pass in python
index = df25.index
number_of_rows = len(index)
print(number_of_rows)
A.append(number_of_rows)
# Out:
# 8

# %%
#Average completion of python course or my_sql or python english or computational thinking
#completion of computational_thinking course above 30 marks pass 
df26 = df100[(df100["computational_thinking"] > 30)]
df26
# Out:
#        Name  python  python_en  mysql  computational_thinking  \
# 16  Guhan S      -1         72     35                      39
#
#     Previous Geekions  CodeKata Score  \
# 16               7310            7630
#
#                                    Department  Rising
# 16  Electronics and Communication Engineering     320

# %%
index = df26.index
number_of_rows = len(index)
print(number_of_rows)
A.append(number_of_rows)
# Out:
# 1

# %%
print(A)
# Out:
# [4, 15, 8, 1]

# %%
#Average completion of python course or my_sql or python english or computational thinking
K1 = len(A)
B = sum(A)
K2 = B/K1
K2
# Out:
# 7.0

# %%
df100 = pd.read_csv('college_2.csv')
df100
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df100.sort_values('Rising')
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 32                    bala      32         49      0                      -1
# 31              AMARNATH D      -1         52     12                      -1
# 30           praveen raj j      24         -1      0                       0
# 29               Abishak s      -1         55     35                       6
# 28           M.Karthikeyan      -1          0      4                       6
# 27       Vimalesh Fernando      -1          0      0                       0
# 24           P.GOVARDHANAN      -1         40      0                      -1
# 23              MUKESH S M      -1         46      0                       0
# 33                    XY Z      -1         20     -1                      -1
# 34               Hariharan      -1         -1     -1                       0
# ...

# %%
final_df = df100.sort_values(by=['Rising'], ascending=False)
final_df
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 8                 shifak N      58          0      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 18          Narasimhan Y L      -1         -1      0                       0
# 9                  Balaji       -1        100     20                       0
# 22             santhoshini      -1         43      0                       0
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 15             Rahul Raj K      -1          0      0                       0
# 19            Leelakrishna      -1          6      4                       0
# 20          PremsagarReddy      -1         20      0                       0
# ...

# %%
#rising star of the week (top 3 candidate who performed well in that particular week)
final_df[0:3]
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 8            shifak N      58          0      0                       0
# 2   Ganesh Ramkumar R      -1         55     24                       6
# 18     Narasimhan Y L      -1         -1      0                       0
#
#     Previous Geekions  CodeKata Score                              Department  \
# 8                5180            8320  Electronics and Electrical Engineering
# 2                8790           10790        Computer Science and Engineering
# 18               4800            6800        Computer Science and Engineering
#
#     Rising
# 8     3140
# 2     2000
# 18    2000

# %%
#Shining stars of the week (top 3 candidates who has highest geekions)
final_df = df100.sort_values(by=['Previous Geekions'], ascending=False)
final_df
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 7                Gowtham R      -1         60      4                       6
# 11    Balaraman Muthupandi      -1          9      0                       0
# 10                Rushitha      -1         15     62                       9
# 12                JPradhap     100          0      0                       0
# 16                 Guhan S      -1         72     35                      39
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# ...

# %%
##Shining stars of the week (top 3 candidates who has highest geekions)
final_df[0:3]
# Out:
#               Name  python  python_en  mysql  computational_thinking  \
# 0    ASHOK KUMAR K     100          0     31                       9
# 1          Chandru       0         20      0                       0
# 3  Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 3              10040           10040
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 3  Electronics and Communication Engineering       0

# %%
index = df100.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 35

# %%
#CodeKata Score
Totalpie = df100["CodeKata Score"].sum()
Totalpie
# Out:
# 238050

# %%
#Department wise codekata performence (pie chart)
#ECE
df101 = df100[(df100['Department'] == 'Electronics and Communication Engineering')]
df101
# Out:
#                Name  python  python_en  mysql  computational_thinking  \
# 3   Bodipudi Harini      -1          0     35                      -1
# 7         Gowtham R      -1         60      4                       6
# 14        Praneetha      -1         23    100                      -1
# 16          Guhan S      -1         72     35                      39
# 24    P.GOVARDHANAN      -1         40      0                      -1
# 29        Abishak s      -1         55     35                       6
# 31       AMARNATH D      -1         52     12                      -1
# 32             bala      32         49      0                      -1
#
#     Previous Geekions  CodeKata Score  \
# 3               10040           10040
# 7                8650            8650
# 14               7170            7730
# 16               7310            7630
# 24               5050            5050
# 29               3220            3220
# 31               1890            1890
# ...

# %%
ECE = df101["CodeKata Score"].sum()
ECE
# Out:
# 45930

# %%
Pie1  = []
Dep1  = []
Pie1.append(ECE)
Dep1.append("ECE")

# %%
ECEpie = (ECE/Totalpie)*100
ECEpie
# Out:
# 19.294265910523

# %%
#Department wise codekata performence (pie chart)
#EEE
df102 = df100[(df100['Department'] == 'Electronics and Electrical Engineering')]
df102
# Out:
#              Name  python  python_en  mysql  computational_thinking  \
# 0   ASHOK KUMAR K     100          0     31                       9
# 4       VIINU V P      -1        100     24                      -1
# 8        shifak N      58          0      0                       0
# 9         Balaji       -1        100     20                       0
# 12       JPradhap     100          0      0                       0
#
#     Previous Geekions  CodeKata Score                              Department  \
# 0               19400           19400  Electronics and Electrical Engineering
# 4                9150            9150  Electronics and Electrical Engineering
# 8                5180            8320  Electronics and Electrical Engineering
# 9                6170            8160  Electronics and Electrical Engineering
# 12               7340            8030  Electronics and Electrical Engineering
#
#     Rising
# 0        0
# 4        0
# 8     3140
# 9     1990
# 12     690

# %%
EEE = df102["CodeKata Score"].sum()
EEE
# Out:
# 53060

# %%
Pie1.append(EEE)
Dep1.append("EEE")

# %%
EEEpie = (EEE/Totalpie)*100
EEEpie
# Out:
# 22.289434992648605

# %%
#Department wise codekata performence (pie chart)
#CSE
df103 = df100[(df100['Department'] == 'Computer Science and Engineering')]
df103
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 15             Rahul Raj K      -1          0      0                       0
# 17            Suryarajan S      -1         63     31                       0
# 18          Narasimhan Y L      -1         -1      0                       0
# 19            Leelakrishna      -1          6      4                       0
# ...

# %%
CSE = df103["CodeKata Score"].sum()
CSE
# Out:
# 139060

# %%
Pie1.append(CSE)
Dep1.append("CSE")

# %%
Pie1
# Out:
# [45930, 53060, 139060]

# %%
Dep1
# Out:
# ['ECE', 'EEE', 'CSE']

# %%
CSEpie = (CSE/Totalpie)*100
CSEpie
# Out:
# 58.416299096828396

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np


#Dep1 = ['ECE', 'EEE', 'CSE'] 
#Pie1 = [45930, 53060, 139060]

# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(Pie1,  labels = Dep1)

# show plot
plt.show()

# %%
#basing on percentages
Dep1P = ['ECE', 'EEE', 'CSE'] 
Pie1P = [19.294265910523,
 22.289434992648605,
 58.416299096828396
]
fig = plt.figure(figsize =(10, 7))
plt.pie(Pie1P,  labels = Dep1P)

# show plot
plt.show()

# %%
#Department wise toppers (horizantal bar graph or any visual representations of your choice)
final_df1 = df101.sort_values(by=['CodeKata Score'], ascending=False)
final_df1
# Out:
#                Name  python  python_en  mysql  computational_thinking  \
# 3   Bodipudi Harini      -1          0     35                      -1
# 7         Gowtham R      -1         60      4                       6
# 14        Praneetha      -1         23    100                      -1
# 16          Guhan S      -1         72     35                      39
# 24    P.GOVARDHANAN      -1         40      0                      -1
# 29        Abishak s      -1         55     35                       6
# 31       AMARNATH D      -1         52     12                      -1
# 32             bala      32         49      0                      -1
#
#     Previous Geekions  CodeKata Score  \
# 3               10040           10040
# 7                8650            8650
# 14               7170            7730
# 16               7310            7630
# 24               5050            5050
# 29               3220            3220
# 31               1890            1890
# ...

# %%
K1 = final_df1[0:3]
K1
# Out:
#                Name  python  python_en  mysql  computational_thinking  \
# 3   Bodipudi Harini      -1          0     35                      -1
# 7         Gowtham R      -1         60      4                       6
# 14        Praneetha      -1         23    100                      -1
#
#     Previous Geekions  CodeKata Score  \
# 3               10040           10040
# 7                8650            8650
# 14               7170            7730
#
#                                    Department  Rising
# 3   Electronics and Communication Engineering       0
# 7   Electronics and Communication Engineering       0
# 14  Electronics and Communication Engineering     560

# %%
final_df2 = df102.sort_values(by=['CodeKata Score'], ascending=False)
final_df2
# Out:
#              Name  python  python_en  mysql  computational_thinking  \
# 0   ASHOK KUMAR K     100          0     31                       9
# 4       VIINU V P      -1        100     24                      -1
# 8        shifak N      58          0      0                       0
# 9         Balaji       -1        100     20                       0
# 12       JPradhap     100          0      0                       0
#
#     Previous Geekions  CodeKata Score                              Department  \
# 0               19400           19400  Electronics and Electrical Engineering
# 4                9150            9150  Electronics and Electrical Engineering
# 8                5180            8320  Electronics and Electrical Engineering
# 9                6170            8160  Electronics and Electrical Engineering
# 12               7340            8030  Electronics and Electrical Engineering
#
#     Rising
# 0        0
# 4        0
# 8     3140
# 9     1990
# 12     690

# %%
K2 = final_df2[0:3]
K2
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K     100          0     31                       9
# 4      VIINU V P      -1        100     24                      -1
# 8       shifak N      58          0      0                       0
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
# 4               9150            9150  Electronics and Electrical Engineering
# 8               5180            8320  Electronics and Electrical Engineering
#
#    Rising
# 0       0
# 4       0
# 8    3140

# %%
final_df3 = df103.sort_values(by=['CodeKata Score'], ascending=False)
final_df3
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 15             Rahul Raj K      -1          0      0                       0
# 17            Suryarajan S      -1         63     31                       0
# 18          Narasimhan Y L      -1         -1      0                       0
# 19            Leelakrishna      -1          6      4                       0
# ...

# %%
K3 = final_df3[0:3]
K3
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 5         Poojitha Y       0         78     35                       0
#
#    Previous Geekions  CodeKata Score                        Department  Rising
# 1              14150           14490  Computer Science and Engineering     340
# 2               8790           10790  Computer Science and Engineering    2000
# 5               7210            8970  Computer Science and Engineering    1760

# %%
#ECE horizontal bar chart
K1.plot.barh(x='Name',y='CodeKata Score',color='green')
import matplotlib.pyplot as plt

plt.title("Electronics and Communication Engineering")
plt.show()

# %%
#EEE horizontal bar chart
K2.plot.barh(x='Name',y='CodeKata Score',color='green')
import matplotlib.pyplot as plt

plt.title("Electronics and Electrical Engineering")
plt.show()

# %%
#CSE horizontal bar chart
import matplotlib.pyplot as plt

K3.plot.barh(x='Name',y='CodeKata Score',color='green')
plt.title("Computer Science and Engineering")
plt.show()
